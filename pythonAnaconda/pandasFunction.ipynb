# %%
import pandas as pd

# %% [markdown]
# CSV dosyalarını okumak için

# %%
df = pd.read_csv("Chocolate Sales.csv")
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# Eksik değerleri, o sütunun ortalamasıyla doldurmak için

# %%
df["Boxes Shipped"].fillna(df["Boxes Shipped"].mean(), inplace=True)
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# Sayısal sütunların özet istatistikleri için

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000

# %% [markdown]
# tekrarlanan satırları kontrol eder

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tekrarlayan satırları siler

# %%
df.drop_duplicates()
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# Sütun isimlerini değiştirmek için

# %%
df.rename(columns={"Amount":"Cost"})
# Out:
#           Sales Person    Country              Product       Date      Cost  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# Veri tipini değiştirmek için

# %%
df["Boxes Shipped"].astype(float)
# Out:
# 0       180.0
# 1        94.0
# 2        91.0
# 3       342.0
# 4       184.0
#         ...
# 1089    323.0
# 1090    119.0
# 1091    217.0
# 1092    384.0
# 1093    344.0
# Name: Boxes Shipped, Length: 1094, dtype: float64

# %% [markdown]
#  SQL benzeri filtreleme

# %%
df.query('Country == "UK" & Product == "White Choc"')
# Out:
#             Sales Person Country     Product       Date    Amount  \
# 172          Brien Boise      UK  White Choc  12-Apr-22   $5,299
# 185       Camilla Castle      UK  White Choc  03-Jan-22   $9,982
# 197  Dennison Crosswaite      UK  White Choc  03-Aug-22   $7,238
# 200       Beverie Moffet      UK  White Choc  30-Jun-22   $6,475
# 272         Barr Faughny      UK  White Choc  05-Jul-22   $1,652
# 312       Curtice Advani      UK  White Choc  01-Feb-22   $1,540
# 362         Husein Augar      UK  White Choc  13-Jan-22  $10,815
# 428         Ches Bonnell      UK  White Choc  03-Jan-22   $3,269
# 675         Jan Morforth      UK  White Choc  22-Jun-22   $8,799
# 690       Jehu Rudeforth      UK  White Choc  29-Jun-22   $1,862
# 715       Andria Kimpton      UK  White Choc  12-May-22   $9,037
# 934           Oby Sorrel      UK  White Choc  27-Jun-22   $1,715
#
#      Boxes Shipped
# 172            167
# 185            187
# 197            265
# 200             76
# ...

# %% [markdown]
# Belirli bir aralıktaki değerleri seçer

# %%
df["Boxes Shipped"].between(0,150)
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1089    False
# 1090     True
# 1091    False
# 1092    False
# 1093    False
# Name: Boxes Shipped, Length: 1094, dtype: bool

# %% [markdown]
# index bazlı seçim yapar

# %%
df.loc[df["Sales Person"] == "Andria Kimpton"]
# Out:
#         Sales Person      Country               Product       Date    Amount  \
# 34    Andria Kimpton       Canada           After Nines  11-May-22   $2,163
# 36    Andria Kimpton           UK        50% Dark Bites  24-Aug-22   $2,653
# 43    Andria Kimpton        India   Spicy Special Slims  23-Feb-22   $6,307
# 59    Andria Kimpton    Australia        50% Dark Bites  02-Jun-22   $4,438
# 60    Andria Kimpton    Australia         Drinking Coco  28-Jun-22   $1,603
# 73    Andria Kimpton  New Zealand   Peanut Butter Cubes  20-Jun-22     $959
# 80    Andria Kimpton          USA       Raspberry Choco  30-Jun-22  $14,504
# 89    Andria Kimpton       Canada  Caramel Stuffed Bars  03-Jan-22   $7,154
# 101   Andria Kimpton          USA      Fruit & Nut Bars  15-Jul-22   $1,456
# 160   Andria Kimpton          USA         85% Dark Bars  05-Apr-22   $8,911
# 323   Andria Kimpton  New Zealand        50% Dark Bites  02-Mar-22   $3,374
# ...

# %% [markdown]
# Belirtilen sütunu veya satırı siler

# %%
df.drop(columns=["Product"])
df.drop(index=[0,101,239])
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# 5          Van Tuxwell      India   Smooth Sliky Salty  06-Jun-22   $5,376
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 1                94
# 2                91
# ...
